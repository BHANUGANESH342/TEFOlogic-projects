# %%
# Importing libraries
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
ca = pd.read_csv(r"C:\Users\rkssp\Downloads\archive (5)\Breast_Cancer.csv") 
ca.head()#TO SHOW THE DATA
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
ca.info()
ca.shape# TO GET THE SHAPE OF THE DATA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
ca.isna().sum() # FOR FINDING THE NULL VALUES
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
list(ca.columns)
# Out:
# ['Age',
#  'Race',
#  'Marital Status',
#  'T Stage ',
#  'N Stage',
#  '6th Stage',
#  'differentiate',
#  'Grade',
#  'A Stage',
#  'Tumor Size',
#  'Estrogen Status',
#  'Progesterone Status',
#  'Regional Node Examined',
#  'Reginol Node Positive',
#  'Survival Months',
#  'Status']

# %%
cafi=ca.drop(['T Stage ',
 'N Stage','6th Stage','Estrogen Status',
 'Progesterone Status','Grade'],axis=1)      #TO DROP THE UNWANTED COLUMNS
cafi
# Out:
#       Age   Race Marital Status              differentiate   A Stage  \
# 0      68  White        Married      Poorly differentiated  Regional
# 1      50  White        Married  Moderately differentiated  Regional
# 2      58  White       Divorced  Moderately differentiated  Regional
# 3      58  White        Married      Poorly differentiated  Regional
# 4      47  White        Married      Poorly differentiated  Regional
# ...   ...    ...            ...                        ...       ...
# 4019   62  Other        Married  Moderately differentiated  Regional
# 4020   56  White       Divorced  Moderately differentiated  Regional
# 4021   68  White        Married  Moderately differentiated  Regional
# 4022   58  Black       Divorced  Moderately differentiated  Regional
# 4023   46  White        Married  Moderately differentiated  Regional
#
#       Tumor Size  Regional Node Examined  Reginol Node Positive  \
# 0              4                      24                      1
# ...

# %%
ca['Marital Status'].unique()          # TO FIND THE UNIQUE
# Out:
# array(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],
#       dtype=object)

# %%
#To ignore warnings
import warnings
warnings.filterwarnings("ignore")
#This is to change a specified value in a column
cafi['Marital Status']=cafi['Marital Status'].map({'Married':2,'Single ':1,'Widowed':0,'Divorced':3,'Separated':4})
cafi
                     #TO MAP THE STRINGS
# Out:
#       Age   Race  Marital Status              differentiate   A Stage  \
# 0      68  White               2      Poorly differentiated  Regional
# 1      50  White               2  Moderately differentiated  Regional
# 2      58  White               3  Moderately differentiated  Regional
# 3      58  White               2      Poorly differentiated  Regional
# 4      47  White               2      Poorly differentiated  Regional
# ...   ...    ...             ...                        ...       ...
# 4019   62  Other               2  Moderately differentiated  Regional
# 4020   56  White               3  Moderately differentiated  Regional
# 4021   68  White               2  Moderately differentiated  Regional
# 4022   58  Black               3  Moderately differentiated  Regional
# 4023   46  White               2  Moderately differentiated  Regional
#
#       Tumor Size  Regional Node Examined  Reginol Node Positive  \
# ...

# %%
ca['Race'].unique()# TO FIND THE UNIQUE
# Out:
# array(['White', 'Black', 'Other'], dtype=object)

# %%
cafi['Race']=cafi['Race'].map({'White':1,'Black':2,'Other':0})
cafi                     #TO MAP THE STRINGS
# Out:
#       Age  Race  Marital Status              differentiate   A Stage  \
# 0      68     1               2      Poorly differentiated  Regional
# 1      50     1               2  Moderately differentiated  Regional
# 2      58     1               3  Moderately differentiated  Regional
# 3      58     1               2      Poorly differentiated  Regional
# 4      47     1               2      Poorly differentiated  Regional
# ...   ...   ...             ...                        ...       ...
# 4019   62     0               2  Moderately differentiated  Regional
# 4020   56     1               3  Moderately differentiated  Regional
# 4021   68     1               2  Moderately differentiated  Regional
# 4022   58     2               3  Moderately differentiated  Regional
# 4023   46     1               2  Moderately differentiated  Regional
#
#       Tumor Size  Regional Node Examined  Reginol Node Positive  \
# 0              4                      24                      1
# ...

# %%
ca['differentiate'].unique()           # TO FIND THE UNIQUE
# Out:
# array(['Poorly differentiated', 'Moderately differentiated',
#        'Well differentiated', 'Undifferentiated'], dtype=object)

# %%
cafi[ 'differentiate']=cafi['differentiate'].map({'Poorly differentiated':1,'Moderately differentiated':2,'Well differentiated':3,'Undifferentiated':0})
cafi                              # TO FIND THE UNIQUE
# Out:
#       Age  Race  Marital Status  differentiate   A Stage  Tumor Size  \
# 0      68     1               2              1  Regional           4
# 1      50     1               2              2  Regional          35
# 2      58     1               3              2  Regional          63
# 3      58     1               2              1  Regional          18
# 4      47     1               2              1  Regional          41
# ...   ...   ...             ...            ...       ...         ...
# 4019   62     0               2              2  Regional           9
# 4020   56     1               3              2  Regional          46
# 4021   68     1               2              2  Regional          22
# 4022   58     2               3              2  Regional          44
# 4023   46     1               2              2  Regional          30
#
#       Regional Node Examined  Reginol Node Positive  Survival Months Status
# ...

# %%
ca['A Stage'].unique()# TO FIND THE UNIQUE
# Out:
# array(['Regional', 'Distant'], dtype=object)

# %%
cafi['A Stage']=cafi['A Stage'].map({'Regional':0,'Distant':1})
cafi                  #TO MAP THE STRINGS
# Out:
#       Age  Race  Marital Status  differentiate  A Stage  Tumor Size  \
# 0      68     1               2              1        0           4
# 1      50     1               2              2        0          35
# 2      58     1               3              2        0          63
# 3      58     1               2              1        0          18
# 4      47     1               2              1        0          41
# ...   ...   ...             ...            ...      ...         ...
# 4019   62     0               2              2        0           9
# 4020   56     1               3              2        0          46
# 4021   68     1               2              2        0          22
# 4022   58     2               3              2        0          44
# 4023   46     1               2              2        0          30
#
#       Regional Node Examined  Reginol Node Positive  Survival Months Status
# ...

# %%
ca['Status'].unique()
# Out:
# array(['Alive', 'Dead'], dtype=object)

# %%
cafi['Status']=cafi['Status'].map({'Dead':0,'Alive':1})
cafi
# Out:
#       Age  Race  Marital Status  differentiate  A Stage  Tumor Size  \
# 0      68     1               2              1        0           4
# 1      50     1               2              2        0          35
# 2      58     1               3              2        0          63
# 3      58     1               2              1        0          18
# 4      47     1               2              1        0          41
# ...   ...   ...             ...            ...      ...         ...
# 4019   62     0               2              2        0           9
# 4020   56     1               3              2        0          46
# 4021   68     1               2              2        0          22
# 4022   58     2               3              2        0          44
# 4023   46     1               2              2        0          30
#
#       Regional Node Examined  Reginol Node Positive  Survival Months  Status
# ...

# %%
cafi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   int64
#  2   Marital Status          4024 non-null   int64
#  3   differentiate           4024 non-null   int64
#  4   A Stage                 4024 non-null   int64
#  5   Tumor Size              4024 non-null   int64
#  6   Regional Node Examined  4024 non-null   int64
#  7   Reginol Node Positive   4024 non-null   int64
#  8   Survival Months         4024 non-null   int64
#  9   Status                  4024 non-null   int64
# dtypes: int64(10)
# memory usage: 314.5 KB

# %%
d3=cafi.corr()
d3                 # TO FIND THE CORRELATION
# Out:
#                              Age      Race  Marital Status  differentiate  \
# Age                     1.000000  0.029053       -0.070231       0.099294
# Race                    0.029053  1.000000       -0.065930      -0.045346
# Marital Status         -0.070231 -0.065930        1.000000      -0.004071
# differentiate           0.099294 -0.045346       -0.004071       1.000000
# A Stage                -0.020860  0.007097        0.021887      -0.039459
# Tumor Size             -0.077215 -0.004629       -0.002072      -0.119367
# Regional Node Examined -0.033345 -0.009975        0.007870      -0.084416
# Reginol Node Positive   0.012586  0.007689        0.016708      -0.135319
# Survival Months        -0.009390 -0.055089        0.003579       0.067669
# Status                 -0.055921 -0.078725        0.003848       0.161398
#
#                          A Stage  Tumor Size  Regional Node Examined  \
# Age                    -0.020860   -0.077215               -0.033345
# ...

# %%
import seaborn as sns
sns.heatmap(d3,vmax=1,vmin=-1,annot=True,linewidth=1,cmap='bwr')      #HEATMAP
# Out:
# <Axes: >

# %%
y=cafi['Status']
x=cafi.drop('Status',axis=1)

# %%
x
# Out:
#       Age  Race  Marital Status  differentiate  A Stage  Tumor Size  \
# 0      68     1               2              1        0           4
# 1      50     1               2              2        0          35
# 2      58     1               3              2        0          63
# 3      58     1               2              1        0          18
# 4      47     1               2              1        0          41
# ...   ...   ...             ...            ...      ...         ...
# 4019   62     0               2              2        0           9
# 4020   56     1               3              2        0          46
# 4021   68     1               2              2        0          22
# 4022   58     2               3              2        0          44
# 4023   46     1               2              2        0          30
#
#       Regional Node Examined  Reginol Node Positive  Survival Months
# 0                         24                      1               60
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4019    1
# 4020    1
# 4021    1
# 4022    1
# 4023    1
# Name: Status, Length: 4024, dtype: int64

# %%
#spliting data to create the model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.describe()
# Out:
#                Age         Race  Marital Status  differentiate      A Stage  \
# count  2696.000000  2696.000000     2696.000000    2696.000000  2696.000000
# mean     53.854599     0.988872        1.846439       1.852003     0.022997
# std       8.979279     0.402988        0.732096       0.643492     0.149922
# min      30.000000     0.000000        0.000000       0.000000     0.000000
# 25%      47.000000     1.000000        2.000000       1.000000     0.000000
# 50%      54.000000     1.000000        2.000000       2.000000     0.000000
# 75%      61.000000     1.000000        2.000000       2.000000     0.000000
# max      69.000000     2.000000        4.000000       3.000000     1.000000
#
#         Tumor Size  Regional Node Examined  Reginol Node Positive  \
# count  2696.000000             2696.000000            2696.000000
# mean     30.042285               14.277819               4.201039
# std      20.556156                8.142992               5.228686
# ...

# %%
y_test.describe()
# Out:
# count    1328.000000
# mean        0.851657
# std         0.355574
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Status, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8975903614457831

# %%
results=pd.DataFrame(columns=['Actual','Predicted']) #To compare the actual and predicted price
results['Actual']=y_test
results['Predicted']=y_pred
results=results.reset_index()
results['Id']=results.index
results
# Out:
#       index  Actual  Predicted    Id
# 0      1718       1          1     0
# 1      1204       1          1     1
# 2      2722       1          1     2
# 3      1937       0          1     3
# 4      1226       1          1     4
# ...     ...     ...        ...   ...
# 1323   3454       1          1  1323
# 1324   1725       1          1  1324
# 1325   1954       1          1  1325
# 1326    168       1          1  1326
# 1327   3728       1          1  1327
#
# [1328 rows x 4 columns]
